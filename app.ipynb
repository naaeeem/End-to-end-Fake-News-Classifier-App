# %% [markdown]
# # Text Preprocessing & Vectorization
# ---

# %% [markdown]
# ## 1. Lowercasing

# %% [markdown]
# ## 2. Removing Punctuation

# %% [markdown]
# ## 3. Tokenization

# %% [markdown]
# ## 4. Removing Stopwords

# %% [markdown]
# ## 5. Stemming

# %% [markdown]
# ## 6. Lemmatization

# %% [markdown]
# ## 7. Stemming vs Lemmatization — Side by Side

# %% [markdown]
# ---
# ## 8. Bag of Words (CountVectorizer)

# %% [markdown]
# ## 9. TF-IDF (TfidfVectorizer)

# %% [markdown]
# ## 10. BoW vs TF-IDF — Comparison

# %% [markdown]
# ## 11. Word2Vec

# %% [markdown]
# ---
# ## Naive Bayes — SMS Spam Classification

# %% [markdown]
# ## 12. Load Dataset

# %% [markdown]
# ## 13. Explore the Dataset

# %% [markdown]
# ## 14. Preprocessing

# %% [markdown]
# ## 15. Vectorization — TF-IDF

# %% [markdown]
# ## 16. Train Naive Bayes Model

# %% [markdown]
# ## 17. Evaluate the Model

# %% [markdown]
# ## 18. Predict on New Messages
