# %% [markdown]
# ## Downloads && Install

# %%
import nltk

# %%
nltk.download('omw-1.4') # Download the Open Multilingual WordNet dataset required by NLTK
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/md.abunaeem/nltk_data...
# True
